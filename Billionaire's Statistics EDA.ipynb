# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import mplcursors

# %% [markdown]
# ## Importing Data

# %%
data = pd.read_csv("C:/Users/Rifat Ahmed/Downloads/Billionaires Statistics Dataset.csv")

# %% [markdown]
# ## 35 Coumns and 2640 Rows

# %%
data.shape
# Out:
# (2640, 35)

# %% [markdown]
# ## Details for each column:

# %%
data.head(2)
# Out:
#    rank  finalWorth          category                personName   age  \
# 0     1      211000  Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000        Automotive                 Elon Musk  51.0
#
#          country    city         source        industries  \
# 0         France   Paris           LVMH  Fashion & Retail
# 1  United States  Austin  Tesla, SpaceX        Automotive
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# 0               France  ...                1.1   $2,715,518,274,227
# 1        United States  ...                7.5  $21,427,700,000,000
#
#   gross_tertiary_education_enrollment  \
# 0                                65.6
# 1                                88.2
#
#   gross_primary_education_enrollment_country life_expectancy_country  \
# 0                                      102.5                    82.5
# 1                                      101.8                    78.5
#
# ...

# %% [markdown]
# <ul>
#     <li>rank: The ranking of the billionaire in terms of wealth.</li>
#     <li>finalWorth: The final net worth of the billionaire in U.S. dollars.</li>
#     <li>category: The category or industry in which the billionaire's business operates.</li>
#     <li>personName: The full name of the billionaire.</li>
#     <li>age: The age of the billionaire.</li>
#     <li>country: The country in which the billionaire resides.</li>
#     <li>city: The city in which the billionaire resides.</li>
#     <li>source: The source of the billionaire's wealth.</li>
#     <li>industries: The industries associated with the billionaire's business interests.</li>
#     <li>countryOfCitizenship: The country of citizenship of the billionaire.</li>
#     <li>organization: The name of the organization or company associated with the billionaire.</li>
#     <li>selfMade: Indicates whether the billionaire is self-made (True/False).</li>
#     <li>status: "D" represents self-made billionaires (Founders/Entrepreneurs) and "U" indicates inherited or unearned wealth</li>
#     <li>gender: The gender of the billionaire.</li>
#     <li>birthDate: The birthdate of the billionaire.</li>
#     <li>lastName: The last name of the billionaire.</li>
#     <li>firstName: The first name of the billionaire.</li>
#     <li>title: The title or honorific of the billionaire.</li>
#     <li>date: The date of data collection.</li>
#     <li>state: The state in which the billionaire resides.</li>
#     <li>residenceStateRegion: The region or state of residence of the billionaire.</li>
#     <li>birthYear: The birth year of the billionaire.</li>
#     <li>birthMonth: The birth month of the billionaire.</li>
#     <li>birthDay: The birth day of the billionaire.</li>
#     <li>cpi_country: Consumer Price Index (CPI) for the billionaire's country.</li>
#     <li>cpi_change_country: CPI change for the billionaire's country.</li>
#     <li>gdp_country: Gross Domestic Product (GDP) for the billionaire's country.</li>
#     <li>gross_tertiary_education_enrollment: Enrollment in tertiary education in the billionaire's country.</li>
#     <li>gross_primary_education_enrollment_country: Enrollment in primary education in the billionaire's country.</li>
#     <li>life_expectancy_country: Life expectancy in the billionaire's country.</li>
#     <li>tax_revenue_country_country: Tax revenue in the billionaire's country.</li>
#     <li>total_tax_rate_country: Total tax rate in the billionaire's country.</li>
#     <li>population_country: Population of the billionaire's country.</li>
#     <li>latitude_country: Latitude coordinate of the billionaire's country.</li>
#     <li>longitude_country: Longitude coordinate of the billionaire's country.</li>
# </ul>

# %% [markdown]
# ## Data Types of Each Column

# %%
data.dtypes
# Out:
# rank                                            int64
# finalWorth                                      int64
# category                                       object
# personName                                     object
# age                                           float64
# country                                        object
# city                                           object
# source                                         object
# industries                                     object
# countryOfCitizenship                           object
# organization                                   object
# selfMade                                         bool
# status                                         object
# gender                                         object
# birthDate                                      object
# lastName                                       object
# firstName                                      object
# ...

# %% [markdown]
# ## Data Formatting

# %%
data.loc[0, 'date']
# Out:
# '4/4/2023 5:01'

# %%
data['date'] = pd.to_datetime(data['date'], format = '%d/%m/%Y %H:%M')

# %%
data.loc[0, 'birthDate']
# Out:
# '3/5/1949 0:00'

# %%
data['birthDate'] = pd.to_datetime(data['birthDate'], format = '%m/%d/%Y %H:%M')

# %%
data[['date','birthDate']].dtypes
# Out:
# date         datetime64[ns]
# birthDate    datetime64[ns]
# dtype: object

# %% [markdown]
# ## Handling Missing Values

# %%
data.isnull().sum()
# Out:
# rank                                             0
# finalWorth                                       0
# category                                         0
# personName                                       0
# age                                             65
# country                                         38
# city                                            72
# source                                           0
# industries                                       0
# countryOfCitizenship                             0
# organization                                  2315
# selfMade                                         0
# status                                           0
# gender                                           0
# birthDate                                       76
# lastName                                         0
# firstName                                        3
# title                                         2301
# ...

# %%
# Replacing Null value as Unknown
data.fillna({'country': 'Unknown'}, inplace = True)
data.fillna({'city':'Unknown'}, inplace= True)
data.fillna({'organization':'Unknown'}, inplace= True)
data.fillna({'title':'Unknown'}, inplace= True)
data.fillna({'state':'Unknown'}, inplace= True)
data.fillna({'residenceStateRegion':'Unknown'}, inplace= True)

# %%
data[['country','city','organization','title','state','residenceStateRegion']].isnull().sum()
# Out:
# country                 0
# city                    0
# organization            0
# title                   0
# state                   0
# residenceStateRegion    0
# dtype: int64

# %% [markdown]
# ## Top 5 Business Categories by Net Worth
#
# <p>The bar plot below illustrates the top 5 business categories by their total net worth in billions. Each bar represents a business category, with its length corresponding to the aggregated net worth of all individuals within that category.</p>

# %%
# Convert Final Worth in Billion
data['final_worth_in_B'] = (data['finalWorth']/1000)

# Find the top 5 Category
category_net_worth = data.groupby('category')['final_worth_in_B'].sum()
top_catagories = category_net_worth.sort_values(ascending = False).head(5)

# Extract top 5 Category name and Total Worth
catergories = top_catagories.index
total_worth = top_catagories.values

#Create a Bar Plot
plt.figure(figsize = (5,3))
plt.barh(catergories, total_worth, color = 'royalblue')
plt.ylabel('Business Category')
plt.xlabel('Total Worth (in billions)')
plt.title('Top 5 Business Categories by Net Worth')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Top 5 Countries by Net Worth
#
# <p>The pie chart below illustrates the top 5 countries by their total net worth in billions. Each slice of the pie represents a country, with its size corresponding to the aggregated net worth of all individuals within that country.</p>

# %%
# Convert Final Worth in Billion
data['final_worth_in_B'] = (data['finalWorth']/1000)

# Find the top 5 Countries
country_group = data.groupby('country')['final_worth_in_B'].sum()
top_countries = country_group.sort_values(ascending = False).head(5)

# Extract top 5 countries name and Total Worth
countries = top_countries.index
total_worth = top_countries.values

#Create a Pie Plot
plt.figure(figsize = (4,4))
plt.pie(total_worth, labels = countries, autopct='%1.1f%%', startangle=140)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# ## Top 5 Youngest Billionaires with Their Ranks
#
# <p>The horizontal bar chart below displays the top 5 youngest billionaires along with their ranks. Each bar represents a billionaire, with its length corresponding to the individual's age.</p>

# %%
# %matplotlib notebook
# Find the 5 youngest billionaires
youngest_billionaires = data.nsmallest(5, 'age')

# Extract the names, ages, and ranks of the 5 youngest billionaires
names = youngest_billionaires['personName']
ages = youngest_billionaires['age']
ranks = youngest_billionaires['rank']
worth = youngest_billionaires['finalWorth']

# Create the bar chart
fig, ax = plt.subplots(figsize=(5, 3))
bars = ax.barh(names, ages, color='royalblue')
ax.set_xlabel('Age')
ax.set_ylabel('Name')
ax.set_title('Top 5 Youngest Billionaires with Their Ranks')

# Add hover functionality using mplcursors
cursor = mplcursors.cursor(bars, hover=True)
cursor.connect("add", lambda sel: sel.annotation.set_text(f'Rank: {ranks.iloc[sel.target.index]}\nNet Worth: ${worth.iloc[sel.target.index]:.1f}B'))

# Display the bar chart
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# ## Age Distribution of Billionaires
#
# The histogram plot below illustrates the age distribution of billionaires in our dataset. The x-axis represents the ages of the billionaires, while the y-axis indicates the frequency (number of billionaires) for each age group.

# %%
# %matplotlib inline

# Plotting the age distribution histogram with a smaller size
plt.figure(figsize=(5, 3))
data['age'].hist(color='royalblue', edgecolor='black')

# Adding labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution of Billionaires')

# Display the plot
plt.tight_layout()  # Adjusts the plot to ensure everything fits without overlap
plt.show()

# %% [markdown]
# ## Distribution of Self-Made vs Inherited Billionaires
#
# <p>The pie chart below illustrates the distribution of self-made versus inherited billionaires in the dataset. Each slice of the pie represents the proportion of billionaires who are self-made compared to those who inherited their wealth.</p>

# %%
# Calculate the counts of each value in the 'SelfMade' column
self_made_counts = data['selfMade'].value_counts()

# Create the pie chart
plt.figure(figsize=(4, 4))
self_made_counts.plot.pie(autopct='%1.1f%%', startangle=90, colors=['LightCoral','MediumSeagreen'], labels=['Self-Made', 'Inherited'], legend=False)

# Add title
plt.title('Distribution of Self-Made vs Inherited Billionaires')

plt.ylabel('')
plt.show()

# %% [markdown]
# # Distribution of Self-Made vs Inherited Billionaires by Gender
#
# <p>The set of pie charts below illustrates the distribution of self-made versus inherited billionaires, categorized by gender. Each pie chart represents the proportion of self-made and inherited billionaires within a specific gender category.</p>

# %%
gender_counts = data['gender'].value_counts()

# Male distribution
male_self_made_counts = data[data['gender'] == 'M']['selfMade'].value_counts()

# Female distribution
female_self_made_counts = data[data['gender'] == 'F']['selfMade'].value_counts()

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(9, 3))

# Overall pie chart
axs[0].pie(gender_counts, autopct='%1.1f%%', startangle=90, colors=['LightCoral','MediumSeagreen'], labels=['Male', 'Female'])
axs[0].set_title('Gender Distribution')

# Male pie chart
axs[1].pie(male_self_made_counts, autopct='%1.1f%%', startangle=90, colors=['LightCoral','MediumSeagreen'], labels=['Self-Made', 'Inherited'])
axs[1].set_title('Self Made Male')

# Female pie chart
axs[2].pie(female_self_made_counts, autopct='%1.1f%%', startangle=90, colors=['LightCoral','MediumSeagreen'], labels=['Self-Made', 'Inherited'])
axs[2].set_title('Self Made Female')

# Adjust layout
plt.tight_layout()
plt.show()
